# %% [markdown]
# # Project - Data Cleaning
#
# ## Introduction
# In this lab, we'll make use of everything we've learned about pandas, data cleaning, and Exploratory Data Analysis. In order to complete this lab, you'll have to make import, clean, combine, reshape, and visualize data to answer questions provided, as well as your own questions!
#
# ## Objectives
# You will be able to:
# * Show mastery of the content covered in this section
#
# ## The Dataset
# In this lab, we'll work with the comprehensive [Super Heroes Dataset](https://www.kaggle.com/claudiodavi/superhero-set/data), which can be found on Kaggle!
#
# ## Goals
# * Use all available pandas knowledge to clean the dataset and deal with null values
# * Use Queries and aggregations to group the data into interesting subsets as needed
# * Use descriptive statistics and data visualization to find answers to questions we may have about the data.
#
# ## Getting Started
#
# In the cell below:
#
# * Import and alias pandas as `pd`
# * Import and alias numpy as `np`
# * Import and alias seaborn as `sns`
# * Import and alias matplotlib.pyplot as `plt`
# * Set matplotlib visualizations to display inline in the notebook

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# For this lab, our dataset is split among two different sources--`heroes_information.csv` and `super_hero_powers.csv`.
#
# Use pandas to read in each file and store them in DataFrames in the appropriate variables below. Then, display the head of each to ensure that everything loaded correctly.

# %%
heroes_df = pd.read_csv('heroes_information.csv')
powers_df = pd.read_csv('super_hero_powers.csv')
heroes_df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %%
powers_df.head()
# Out:
#     hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0      3-D Man     True                False               False
# 1       A-Bomb    False                 True               False
# 2   Abe Sapien     True                 True               False
# 3     Abin Sur    False                False                True
# 4  Abomination    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
# 3                  False            False       False    False
# 4                  False            False       False    False
#
#    Energy Absorption  Flight     ...      Web Creation  Reality Warping  \
# 0              False   False     ...             False            False
# 1              False   False     ...             False            False
# 2              False   False     ...             False            False
# 3              False   False     ...             False            False
# 4              False   False     ...             False            False
#
#    Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# 0       False             False        False          False
# 1       False             False        False          False
# 2       False             False        False          False
# 3       False             False        False          False
# 4       False             False        False          False
#
#    Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient
# 0                  False          False        False       False
# 1                  False          False        False       False
# 2                  False          False        False       False
# 3                  False          False        False       False
# 4                  False          False        False       False
#
# [5 rows x 168 columns]

# %% [markdown]
# It looks as if the heroes information dataset contained an index column.  We did not specify that this dataset contained an index column, because we hadn't seen it yet. Pandas does not know how to tell apart an index column from any other data, so it stored it with the column name `Unnamed: 0`.
#
# Our DataFrame provided row indices by default, so this column is not needed.  Drop it from the DataFrame in place in the cell below, and then display the head of `heroes_df` to ensure that it worked properly.

# %%
heroes_df = heroes_df.drop(['Unnamed: 0'], axis=1)
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %% [markdown]
# ## Familiarize Yourself With the Dataset
#
# The first step in our Exploratory Data Analysis will be to get familiar with the data.  This step includes:
#
# * Understanding the dimensionality of your dataset
# * Investigating what type of data it contains, and the data types used to store it
# * Discovering how missing values are encoded, and how many there are
# * Getting a feel for what information it does and doesnt contain
#
# In the cell below, get the descriptive statistics of each DataFrame.

# %%
print(len(heroes_df))
heroes_df.isna().sum()
# Out:
# 734
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         2
# dtype: int64

# %%
print(len(powers_df))
powers_df.isna().sum()
# Out:
# 667
# hero_names               0
# Agility                  0
# Accelerated Healing      0
# Lantern Power Ring       0
# Dimensional Awareness    0
# Cold Resistance          0
# Durability               0
# Stealth                  0
# Energy Absorption        0
# Flight                   0
# Danger Sense             0
# Underwater breathing     0
# Marksmanship             0
# Weapons Master           0
# Power Augmentation       0
# Animal Attributes        0
# Longevity                0
# Intelligence             0
# Super Strength           0
# Cryokinesis              0
# Telepathy                0
# Energy Armor             0
# Energy Blasts            0
# Duplication              0
# Size Changing            0
# Density Control          0
# Stamina                  0
# Astral Travel            0
# Audio Control            0
# Dexterity                0
#                         ..
# Intuitive aptitude       0
# Vision - Microscopic     0
# Melting                  0
# Wind Control             0
# Super Breath             0
# Wallcrawling             0
# Vision - Night           0
# Vision - Infrared        0
# Grim Reaping             0
# Matter Absorption        0
# The Force                0
# Resurrection             0
# Terrakinesis             0
# Vision - Heat            0
# Vitakinesis              0
# Radar Sense              0
# Qwardian Power Ring      0
# Weather Control          0
# Vision - X-Ray           0
# Vision - Thermal         0
# Web Creation             0
# Reality Warping          0
# Odin Force               0
# Symbiote Costume         0
# Speed Force              0
# Phoenix Force            0
# Molecular Dissipation    0
# Vision - Cryo            0
# Omnipresent              0
# Omniscient               0
# Length: 168, dtype: int64

# %% [markdown]
# ## Dealing with Null Values
#
# Starting in the cell below, detect and deal with any null values in either data frame.  Then, explain your methodology for detecting and dealing with outliers in the markdown section below.  Be sure to explain your strategy for dealing with null values in numeric columns, as well as your strategy for dealing with null values in non-numeric columns.
#
# Note that if you need to add more cells to write code in, you can do this by:
#
# **1.** Highlighting a cell and then pressing `ESC` to enter command mode.
# **2.** Press `A` to add a cell above the highlighted cell, or `B` to add a cell below the highlighted cell.
#
# Describe your strategy below this line:
# ____________________________________________________________________________________________________________________________

# %% [markdown]
# The only null values I noticed were in the heroes_df dataset. There were a 15 nans in the publisher column and 2 in the weights category.

# %% [markdown]
# There are a few options I have here, e.g. deleting the row, replacing the nan with the mean or meadin of the col or even delting the column entirely. But since it is such a small number of data and to save time, I will just delete the row with any Nans.

# %%
heroes_df['Weight'].fillna(heroes_df['Weight'].mean(), inplace=True)

# %%
#heroes_df = heroes_df.dropna()
heroes_df.isna().sum()
# Out:
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         0
# dtype: int64

# %%
powers_df.isna().any()
# Out:
# hero_names               False
# Agility                  False
# Accelerated Healing      False
# Lantern Power Ring       False
# Dimensional Awareness    False
# Cold Resistance          False
# Durability               False
# Stealth                  False
# Energy Absorption        False
# Flight                   False
# Danger Sense             False
# Underwater breathing     False
# Marksmanship             False
# Weapons Master           False
# Power Augmentation       False
# Animal Attributes        False
# Longevity                False
# Intelligence             False
# Super Strength           False
# Cryokinesis              False
# Telepathy                False
# Energy Armor             False
# Energy Blasts            False
# Duplication              False
# Size Changing            False
# Density Control          False
# Stamina                  False
# Astral Travel            False
# Audio Control            False
# Dexterity                False
#                          ...
# Intuitive aptitude       False
# Vision - Microscopic     False
# Melting                  False
# Wind Control             False
# Super Breath             False
# Wallcrawling             False
# Vision - Night           False
# Vision - Infrared        False
# Grim Reaping             False
# Matter Absorption        False
# The Force                False
# Resurrection             False
# Terrakinesis             False
# Vision - Heat            False
# Vitakinesis              False
# Radar Sense              False
# Qwardian Power Ring      False
# Weather Control          False
# Vision - X-Ray           False
# Vision - Thermal         False
# Web Creation             False
# Reality Warping          False
# Odin Force               False
# Symbiote Costume         False
# Speed Force              False
# Phoenix Force            False
# Molecular Dissipation    False
# Vision - Cryo            False
# Omnipresent              False
# Omniscient               False
# Length: 168, dtype: bool

# %%
powers_df.isna().any().any()
# Out:
# False

# %% [markdown]
# ## Joining, Grouping, and Aggregating
#
# In the cell below, join the two DataFrames.  Think about which sort of join you should use, as well as which columns you should join on.  Rename columns and manipulate as needed.
#
# **_HINT:_** If the join throws an error message, consider settin the the column you want to join on as the index for each DataFrame.

# %%
powers_df.rename(columns={'hero_names': 'name'}, inplace=True)

# %%
powers_df  = powers_df.astype('str')

# %%
hero_power_df = powers_df.set_index('name').join(heroes_df.set_index('name'), how='inner')
hero_power_df
# Out:
#                  Agility Accelerated Healing Lantern Power Ring  \
# name
# A-Bomb             False                True              False
# Abe Sapien          True                True              False
# Abin Sur           False               False               True
# Abomination        False                True              False
# Abraxas            False               False              False
# Absorbing Man      False               False              False
# Adam Monroe        False                True              False
# Adam Strange       False               False              False
# Agent Bob          False               False              False
# Agent Zero         False               False              False
# Air-Walker         False               False              False
# Ajax                True               False              False
# Alan Scott         False               False              False
# Alex Mercer         True                True              False
# Alex Woolsly       False               False              False
# Alien               True               False              False
# Allan Quatermain   False               False              False
# Amazo               True               False               True
# Ammo               False               False              False
# Ando Masahashi     False               False              False
# Angel               True                True              False
# Angel               True                True              False
# Angel Dust          True               False              False
# Angel Salvadore    False               False              False
# Angela             False               False              False
# Animal Man         False               False              False
# Annihilus           True               False              False
# Ant-Man            False               False              False
# Ant-Man II          True               False              False
# Anti-Monitor       False                True              False
# ...                  ...                 ...                ...
# Vindicator         False               False              False
# Violator           False               False              False
# Violet Parr        False               False              False
# Vision             False               False              False
# Vixen               True                True              False
# Vulture             True               False              False
# Walrus             False               False              False
# War Machine        False               False              False
# Warlock             True               False              False
# Warp               False               False              False
# Warpath             True               False              False
# Wasp                True               False              False
# Watcher            False               False              False
# Weapon XI           True                True              False
# White Canary        True               False              False
# Wildfire           False               False              False
# Winter Soldier     False               False              False
# Wolfsbane          False               False              False
# Wolverine           True                True              False
# Wonder Girl         True               False              False
# Wonder Man         False               False              False
# Wonder Woman       False                True              False
# X-23                True                True              False
# X-Man              False               False              False
# Yellowjacket       False               False              False
# Yellowjacket II    False               False              False
# Ymir               False               False              False
# Yoda                True               False              False
# Zatanna            False               False              False
# Zoom               False               False              False
#
#                  Dimensional Awareness Cold Resistance Durability Stealth  \
# name
# A-Bomb                           False           False       True   False
# Abe Sapien                       False            True       True   False
# Abin Sur                         False           False      False   False
# Abomination                      False           False      False   False
# Abraxas                           True           False      False   False
# Absorbing Man                    False            True       True   False
# Adam Monroe                      False           False      False   False
# Adam Strange                     False           False       True    True
# Agent Bob                        False           False      False    True
# Agent Zero                       False           False      False   False
# Air-Walker                       False           False      False   False
# Ajax                             False           False      False   False
# Alan Scott                       False           False      False   False
# Alex Mercer                      False           False      False    True
# Alex Woolsly                     False           False      False   False
# Alien                            False            True       True    True
# Allan Quatermain                 False           False      False   False
# Amazo                            False           False       True   False
# Ammo                             False           False      False   False
# Ando Masahashi                   False           False      False   False
# Angel                            False           False       True    True
# Angel                            False           False       True    True
# Angel Dust                       False           False      False   False
# Angel Salvadore                  False           False      False   False
# Angela                           False           False      False   False
# Animal Man                       False           False      False   False
# Annihilus                        False           False       True   False
# Ant-Man                          False           False      False   False
# Ant-Man II                       False           False      False    True
# Anti-Monitor                      True           False       True   False
# ...                                ...             ...        ...     ...
# Vindicator                       False           False       True   False
# Violator                         False           False       True   False
# Violet Parr                      False           False      False    True
# Vision                           False           False       True    True
# Vixen                            False           False      False    True
# Vulture                          False           False      False   False
# Walrus                           False           False       True   False
# War Machine                      False           False       True   False
# Warlock                          False           False       True   False
# Warp                             False           False      False   False
# Warpath                          False            True       True   False
# Wasp                             False           False      False    True
# Watcher                           True           False      False   False
# Weapon XI                        False           False      False   False
# White Canary                     False           False      False    True
# Wildfire                         False           False      False   False
# Winter Soldier                   False           False      False   False
# Wolfsbane                        False           False      False   False
# Wolverine                        False            True       True    True
# Wonder Girl                      False           False       True   False
# Wonder Man                       False           False       True   False
# Wonder Woman                     False           False       True   False
# X-23                             False           False       True    True
# X-Man                            False           False      False   False
# Yellowjacket                     False           False      False   False
# Yellowjacket II                  False           False      False   False
# Ymir                             False            True       True   False
# Yoda                             False           False      False    True
# Zatanna                          False           False      False   False
# Zoom                             False           False      False   False
#
#                  Energy Absorption Flight Danger Sense  ...   Omniscient  \
# name                                                    ...
# A-Bomb                       False  False        False  ...        False
# Abe Sapien                   False  False        False  ...        False
# Abin Sur                     False  False        False  ...        False
# Abomination                  False  False        False  ...        False
# Abraxas                      False   True        False  ...        False
# Absorbing Man                 True  False        False  ...        False
# Adam Monroe                  False  False        False  ...        False
# Adam Strange                 False   True        False  ...        False
# Agent Bob                    False  False        False  ...        False
# Agent Zero                    True  False        False  ...        False
# Air-Walker                   False   True        False  ...        False
# Ajax                         False  False        False  ...        False
# Alan Scott                   False   True         True  ...        False
# Alex Mercer                   True  False         True  ...        False
# Alex Woolsly                 False  False        False  ...        False
# Alien                        False  False        False  ...        False
# Allan Quatermain             False  False        False  ...        False
# Amazo                        False   True        False  ...        False
# Ammo                         False  False        False  ...        False
# Ando Masahashi               False  False        False  ...        False
# Angel                        False   True        False  ...        False
# Angel                        False   True        False  ...        False
# Angel Dust                   False  False        False  ...        False
# Angel Salvadore              False   True        False  ...        False
# Angela                       False  False        False  ...        False
# Animal Man                   False  False        False  ...        False
# Annihilus                    False   True        False  ...        False
# Ant-Man                      False  False        False  ...        False
# Ant-Man II                   False  False        False  ...        False
# Anti-Monitor                  True   True        False  ...        False
# ...                            ...    ...          ...  ...          ...
# Vindicator                   False   True        False  ...        False
# Violator                     False  False        False  ...        False
# Violet Parr                  False  False        False  ...        False
# Vision                        True   True        False  ...        False
# Vixen                        False   True         True  ...        False
# Vulture                      False   True        False  ...        False
# Walrus                       False  False        False  ...        False
# War Machine                   True   True        False  ...        False
# Warlock                      False   True        False  ...        False
# Warp                         False   True        False  ...        False
# Warpath                      False  False        False  ...        False
# Wasp                         False   True        False  ...        False
# Watcher                      False   True        False  ...        False
# Weapon XI                    False  False        False  ...        False
# White Canary                 False  False        False  ...        False
# Wildfire                      True   True        False  ...        False
# Winter Soldier               False  False        False  ...        False
# Wolfsbane                    False  False        False  ...        False
# Wolverine                    False  False        False  ...        False
# Wonder Girl                  False   True        False  ...        False
# Wonder Man                   False   True        False  ...        False
# Wonder Woman                 False   True        False  ...        False
# X-23                         False  False        False  ...        False
# X-Man                        False   True        False  ...        False
# Yellowjacket                 False  False        False  ...        False
# Yellowjacket II              False   True        False  ...        False
# Ymir                         False  False        False  ...        False
# Yoda                         False  False         True  ...        False
# Zatanna                      False  False        False  ...        False
# Zoom                         False  False        False  ...        False
#
#                   Gender Eye color               Race        Hair color  \
# name
# A-Bomb              Male    yellow              Human           No Hair
# Abe Sapien          Male      blue      Icthyo Sapien           No Hair
# Abin Sur            Male      blue            Ungaran           No Hair
# Abomination         Male     green  Human / Radiation           No Hair
# Abraxas             Male      blue      Cosmic Entity             Black
# Absorbing Man       Male      blue              Human           No Hair
# Adam Monroe         Male      blue                  -             Blond
# Adam Strange        Male      blue              Human             Blond
# Agent Bob           Male     brown              Human             Brown
# Agent Zero          Male         -                  -                 -
# Air-Walker          Male      blue                  -             White
# Ajax                Male     brown             Cyborg             Black
# Alan Scott          Male      blue                  -             Blond
# Alex Mercer         Male         -              Human                 -
# Alex Woolsly        Male         -                  -                 -
# Alien               Male         -    Xenomorph XX121           No Hair
# Allan Quatermain    Male         -                  -                 -
# Amazo               Male       red            Android                 -
# Ammo                Male     brown              Human             Black
# Ando Masahashi      Male         -                  -                 -
# Angel               Male      blue                  -             Blond
# Angel               Male         -            Vampire                 -
# Angel Dust        Female    yellow             Mutant             Black
# Angel Salvadore   Female     brown                  -             Black
# Angela            Female         -                  -                 -
# Animal Man          Male      blue              Human             Blond
# Annihilus           Male     green                  -           No Hair
# Ant-Man             Male      blue              Human             Blond
# Ant-Man II          Male      blue              Human             Blond
# Anti-Monitor        Male    yellow      God / Eternal           No Hair
# ...                  ...       ...                ...               ...
# Vindicator          Male         -                  -                 -
# Violator            Male         -                  -                 -
# Violet Parr       Female    violet              Human             Black
# Vision              Male      gold            Android           No Hair
# Vixen             Female     amber              Human             Black
# Vulture             Male     brown              Human           No Hair
# Walrus              Male      blue              Human             Black
# War Machine         Male     brown              Human             Brown
# Warlock             Male       red                  -             Blond
# Warp                Male     brown                  -             Black
# Warpath             Male     brown             Mutant             Black
# Wasp              Female      blue              Human            Auburn
# Watcher             Male         -                  -                 -
# Weapon XI           Male         -                  -                 -
# White Canary      Female     brown              Human             Black
# Wildfire            Male         -                  -                 -
# Winter Soldier      Male     brown              Human             Brown
# Wolfsbane         Female     green                  -            Auburn
# Wolverine           Male      blue             Mutant             Black
# Wonder Girl       Female      blue           Demi-God             Blond
# Wonder Man          Male       red                  -             Black
# Wonder Woman      Female      blue             Amazon             Black
# X-23              Female     green     Mutant / Clone             Black
# X-Man               Male      blue                  -             Brown
# Yellowjacket        Male      blue              Human             Blond
# Yellowjacket II   Female      blue              Human  Strawberry Blond
# Ymir                Male     white        Frost Giant           No Hair
# Yoda                Male     brown     Yoda's species             White
# Zatanna           Female      blue              Human             Black
# Zoom                Male       red                  -             Brown
#
#                  Height          Publisher Skin color Alignment Weight
# name
# A-Bomb            203.0      Marvel Comics          -      good  441.0
# Abe Sapien        191.0  Dark Horse Comics       blue      good   65.0
# Abin Sur          185.0          DC Comics        red      good   90.0
# Abomination       203.0      Marvel Comics          -       bad  441.0
# Abraxas           -99.0      Marvel Comics          -       bad  -99.0
# Absorbing Man     193.0      Marvel Comics          -       bad  122.0
# Adam Monroe       -99.0       NBC - Heroes          -      good  -99.0
# Adam Strange      185.0          DC Comics          -      good   88.0
# Agent Bob         178.0      Marvel Comics          -      good   81.0
# Agent Zero        191.0      Marvel Comics          -      good  104.0
# Air-Walker        188.0      Marvel Comics          -       bad  108.0
# Ajax              193.0      Marvel Comics          -       bad   90.0
# Alan Scott        180.0          DC Comics          -      good   90.0
# Alex Mercer       -99.0          Wildstorm          -       bad  -99.0
# Alex Woolsly      -99.0       NBC - Heroes          -      good  -99.0
# Alien             244.0  Dark Horse Comics      black       bad  169.0
# Allan Quatermain  -99.0          Wildstorm          -      good  -99.0
# Amazo             257.0          DC Comics          -       bad  173.0
# Ammo              188.0      Marvel Comics          -       bad  101.0
# Ando Masahashi    -99.0       NBC - Heroes          -      good  -99.0
# Angel             183.0      Marvel Comics          -      good   68.0
# Angel             -99.0  Dark Horse Comics          -      good  -99.0
# Angel Dust        165.0      Marvel Comics          -      good   57.0
# Angel Salvadore   163.0      Marvel Comics          -      good   54.0
# Angela            -99.0       Image Comics          -       bad  -99.0
# Animal Man        183.0          DC Comics          -      good   83.0
# Annihilus         180.0      Marvel Comics          -       bad   90.0
# Ant-Man           211.0      Marvel Comics          -      good  122.0
# Ant-Man II        183.0      Marvel Comics          -      good   86.0
# Anti-Monitor       61.0          DC Comics          -       bad  -99.0
# ...                 ...                ...        ...       ...    ...
# Vindicator        -99.0      Marvel Comics          -      good  -99.0
# Violator          -99.0       Image Comics          -       bad  -99.0
# Violet Parr       137.0  Dark Horse Comics          -      good   41.0
# Vision            191.0      Marvel Comics        red      good  135.0
# Vixen             175.0          DC Comics          -      good   63.0
# Vulture           180.0      Marvel Comics          -       bad   79.0
# Walrus            183.0      Marvel Comics          -       bad  162.0
# War Machine       185.0      Marvel Comics          -      good   95.0
# Warlock           188.0      Marvel Comics          -      good  108.0
# Warp              173.0          DC Comics          -       bad   67.0
# Warpath           218.0      Marvel Comics          -      good  158.0
# Wasp              163.0      Marvel Comics          -      good   50.0
# Watcher           -99.0      Marvel Comics          -      good  -99.0
# Weapon XI         -99.0      Marvel Comics          -       bad  -99.0
# White Canary      -99.0          DC Comics          -       bad  -99.0
# Wildfire          -99.0          DC Comics          -      good  -99.0
# Winter Soldier    175.0      Marvel Comics          -      good  117.0
# Wolfsbane         366.0      Marvel Comics          -      good  473.0
# Wolverine         160.0      Marvel Comics          -      good  135.0
# Wonder Girl       165.0          DC Comics          -      good   51.0
# Wonder Man        188.0      Marvel Comics          -      good  171.0
# Wonder Woman      183.0          DC Comics          -      good   74.0
# X-23              155.0      Marvel Comics          -      good   50.0
# X-Man             175.0      Marvel Comics          -      good   61.0
# Yellowjacket      183.0      Marvel Comics          -      good   83.0
# Yellowjacket II   165.0      Marvel Comics          -      good   52.0
# Ymir              304.8      Marvel Comics      white      good  -99.0
# Yoda               66.0       George Lucas      green      good   17.0
# Zatanna           170.0          DC Comics          -      good   57.0
# Zoom              185.0          DC Comics          -       bad   81.0
#
# [660 rows x 176 columns]

# %% [markdown]
# In the cell below, subset male and female heroes into different dataframes.  Create a scatterplot of the height and weight of each hero, with weight as the y-axis.  Plot both the male and female heroes subset into each dataframe, and make the color for each point in the scatterplot correspond to the gender of the superhero.

# %%
male_df = hero_power_df[hero_power_df["Gender"] == 'Male']
female_df = hero_power_df[hero_power_df["Gender"] == 'Female']
male_df
# Out:
#                  Agility Accelerated Healing Lantern Power Ring  \
# name
# A-Bomb             False                True              False
# Abe Sapien          True                True              False
# Abin Sur           False               False               True
# Abomination        False                True              False
# Abraxas            False               False              False
# Absorbing Man      False               False              False
# Adam Monroe        False                True              False
# Adam Strange       False               False              False
# Agent Bob          False               False              False
# Agent Zero         False               False              False
# Air-Walker         False               False              False
# Ajax                True               False              False
# Alan Scott         False               False              False
# Alex Mercer         True                True              False
# Alex Woolsly       False               False              False
# Alien               True               False              False
# Allan Quatermain   False               False              False
# Amazo               True               False               True
# Ammo               False               False              False
# Ando Masahashi     False               False              False
# Angel               True                True              False
# Angel               True                True              False
# Animal Man         False               False              False
# Annihilus           True               False              False
# Ant-Man            False               False              False
# Ant-Man II          True               False              False
# Anti-Monitor       False                True              False
# Anti-Spawn         False               False              False
# Anti-Venom         False                True              False
# Apocalypse          True                True              False
# ...                  ...                 ...                ...
# Triton              True               False              False
# Ultron              True               False              False
# Utgard-Loki        False               False              False
# Vanisher           False               False              False
# Vegeta              True                True              False
# Venom              False                True              False
# Venom II            True               False              False
# Venom III           True                True              False
# Venompool           True                True              False
# Vibe               False               False              False
# Vindicator         False               False              False
# Violator           False               False              False
# Vision             False               False              False
# Vulture             True               False              False
# Walrus             False               False              False
# War Machine        False               False              False
# Warlock             True               False              False
# Warp               False               False              False
# Warpath             True               False              False
# Watcher            False               False              False
# Weapon XI           True                True              False
# Wildfire           False               False              False
# Winter Soldier     False               False              False
# Wolverine           True                True              False
# Wonder Man         False               False              False
# X-Man              False               False              False
# Yellowjacket       False               False              False
# Ymir               False               False              False
# Yoda                True               False              False
# Zoom               False               False              False
#
#                  Dimensional Awareness Cold Resistance Durability Stealth  \
# name
# A-Bomb                           False           False       True   False
# Abe Sapien                       False            True       True   False
# Abin Sur                         False           False      False   False
# Abomination                      False           False      False   False
# Abraxas                           True           False      False   False
# Absorbing Man                    False            True       True   False
# Adam Monroe                      False           False      False   False
# Adam Strange                     False           False       True    True
# Agent Bob                        False           False      False    True
# Agent Zero                       False           False      False   False
# Air-Walker                       False           False      False   False
# Ajax                             False           False      False   False
# Alan Scott                       False           False      False   False
# Alex Mercer                      False           False      False    True
# Alex Woolsly                     False           False      False   False
# Alien                            False            True       True    True
# Allan Quatermain                 False           False      False   False
# Amazo                            False           False       True   False
# Ammo                             False           False      False   False
# Ando Masahashi                   False           False      False   False
# Angel                            False           False       True    True
# Angel                            False           False       True    True
# Animal Man                       False           False      False   False
# Annihilus                        False           False       True   False
# Ant-Man                          False           False      False   False
# Ant-Man II                       False           False      False    True
# Anti-Monitor                      True           False       True   False
# Anti-Spawn                       False           False       True   False
# Anti-Venom                       False           False       True   False
# Apocalypse                       False           False      False   False
# ...                                ...             ...        ...     ...
# Triton                           False            True       True   False
# Ultron                           False           False       True    True
# Utgard-Loki                      False           False       True   False
# Vanisher                         False           False      False   False
# Vegeta                           False           False      False   False
# Venom                            False           False       True   False
# Venom II                         False           False       True   False
# Venom III                        False           False       True   False
# Venompool                         True           False       True    True
# Vibe                              True           False      False   False
# Vindicator                       False           False       True   False
# Violator                         False           False       True   False
# Vision                           False           False       True    True
# Vulture                          False           False      False   False
# Walrus                           False           False       True   False
# War Machine                      False           False       True   False
# Warlock                          False           False       True   False
# Warp                             False           False      False   False
# Warpath                          False            True       True   False
# Watcher                           True           False      False   False
# Weapon XI                        False           False      False   False
# Wildfire                         False           False      False   False
# Winter Soldier                   False           False      False   False
# Wolverine                        False            True       True    True
# Wonder Man                       False           False       True   False
# X-Man                            False           False      False   False
# Yellowjacket                     False           False      False   False
# Ymir                             False            True       True   False
# Yoda                             False           False      False    True
# Zoom                             False           False      False   False
#
#                  Energy Absorption Flight Danger Sense  ...   Omniscient  \
# name                                                    ...
# A-Bomb                       False  False        False  ...        False
# Abe Sapien                   False  False        False  ...        False
# Abin Sur                     False  False        False  ...        False
# Abomination                  False  False        False  ...        False
# Abraxas                      False   True        False  ...        False
# Absorbing Man                 True  False        False  ...        False
# Adam Monroe                  False  False        False  ...        False
# Adam Strange                 False   True        False  ...        False
# Agent Bob                    False  False        False  ...        False
# Agent Zero                    True  False        False  ...        False
# Air-Walker                   False   True        False  ...        False
# Ajax                         False  False        False  ...        False
# Alan Scott                   False   True         True  ...        False
# Alex Mercer                   True  False         True  ...        False
# Alex Woolsly                 False  False        False  ...        False
# Alien                        False  False        False  ...        False
# Allan Quatermain             False  False        False  ...        False
# Amazo                        False   True        False  ...        False
# Ammo                         False  False        False  ...        False
# Ando Masahashi               False  False        False  ...        False
# Angel                        False   True        False  ...        False
# Angel                        False   True        False  ...        False
# Animal Man                   False  False        False  ...        False
# Annihilus                    False   True        False  ...        False
# Ant-Man                      False  False        False  ...        False
# Ant-Man II                   False  False        False  ...        False
# Anti-Monitor                  True   True        False  ...        False
# Anti-Spawn                   False  False        False  ...        False
# Anti-Venom                   False  False         True  ...        False
# Apocalypse                    True   True        False  ...        False
# ...                            ...    ...          ...  ...          ...
# Triton                       False  False        False  ...        False
# Ultron                        True   True        False  ...        False
# Utgard-Loki                  False  False        False  ...        False
# Vanisher                     False  False        False  ...        False
# Vegeta                       False   True        False  ...        False
# Venom                        False  False         True  ...        False
# Venom II                     False  False        False  ...        False
# Venom III                    False  False         True  ...        False
# Venompool                    False  False         True  ...        False
# Vibe                         False  False        False  ...        False
# Vindicator                   False   True        False  ...        False
# Violator                     False  False        False  ...        False
# Vision                        True   True        False  ...        False
# Vulture                      False   True        False  ...        False
# Walrus                       False  False        False  ...        False
# War Machine                   True   True        False  ...        False
# Warlock                      False   True        False  ...        False
# Warp                         False   True        False  ...        False
# Warpath                      False  False        False  ...        False
# Watcher                      False   True        False  ...        False
# Weapon XI                    False  False        False  ...        False
# Wildfire                      True   True        False  ...        False
# Winter Soldier               False  False        False  ...        False
# Wolverine                    False  False        False  ...        False
# Wonder Man                   False   True        False  ...        False
# X-Man                        False   True        False  ...        False
# Yellowjacket                 False  False        False  ...        False
# Ymir                         False  False        False  ...        False
# Yoda                         False  False         True  ...        False
# Zoom                         False  False        False  ...        False
#
#                  Gender Eye color               Race        Hair color Height  \
# name
# A-Bomb             Male    yellow              Human           No Hair  203.0
# Abe Sapien         Male      blue      Icthyo Sapien           No Hair  191.0
# Abin Sur           Male      blue            Ungaran           No Hair  185.0
# Abomination        Male     green  Human / Radiation           No Hair  203.0
# Abraxas            Male      blue      Cosmic Entity             Black  -99.0
# Absorbing Man      Male      blue              Human           No Hair  193.0
# Adam Monroe        Male      blue                  -             Blond  -99.0
# Adam Strange       Male      blue              Human             Blond  185.0
# Agent Bob          Male     brown              Human             Brown  178.0
# Agent Zero         Male         -                  -                 -  191.0
# Air-Walker         Male      blue                  -             White  188.0
# Ajax               Male     brown             Cyborg             Black  193.0
# Alan Scott         Male      blue                  -             Blond  180.0
# Alex Mercer        Male         -              Human                 -  -99.0
# Alex Woolsly       Male         -                  -                 -  -99.0
# Alien              Male         -    Xenomorph XX121           No Hair  244.0
# Allan Quatermain   Male         -                  -                 -  -99.0
# Amazo              Male       red            Android                 -  257.0
# Ammo               Male     brown              Human             Black  188.0
# Ando Masahashi     Male         -                  -                 -  -99.0
# Angel              Male      blue                  -             Blond  183.0
# Angel              Male         -            Vampire                 -  -99.0
# Animal Man         Male      blue              Human             Blond  183.0
# Annihilus          Male     green                  -           No Hair  180.0
# Ant-Man            Male      blue              Human             Blond  211.0
# Ant-Man II         Male      blue              Human             Blond  183.0
# Anti-Monitor       Male    yellow      God / Eternal           No Hair   61.0
# Anti-Spawn         Male         -                  -                 -  -99.0
# Anti-Venom         Male      blue           Symbiote             Blond  229.0
# Apocalypse         Male       red             Mutant             Black  213.0
# ...                 ...       ...                ...               ...    ...
# Triton             Male     green            Inhuman           No Hair  188.0
# Ultron             Male       red            Android                 -  206.0
# Utgard-Loki        Male      blue        Frost Giant             White   15.2
# Vanisher           Male     green                  -           No Hair  165.0
# Vegeta             Male         -             Saiyan             Black  168.0
# Venom              Male      blue           Symbiote  Strawberry Blond  191.0
# Venom II           Male     brown                  -             Black  175.0
# Venom III          Male     brown           Symbiote             Brown  229.0
# Venompool          Male         -           Symbiote                 -  226.0
# Vibe               Male     brown              Human             Black  178.0
# Vindicator         Male         -                  -                 -  -99.0
# Violator           Male         -                  -                 -  -99.0
# Vision             Male      gold            Android           No Hair  191.0
# Vulture            Male     brown              Human           No Hair  180.0
# Walrus             Male      blue              Human             Black  183.0
# War Machine        Male     brown              Human             Brown  185.0
# Warlock            Male       red                  -             Blond  188.0
# Warp               Male     brown                  -             Black  173.0
# Warpath            Male     brown             Mutant             Black  218.0
# Watcher            Male         -                  -                 -  -99.0
# Weapon XI          Male         -                  -                 -  -99.0
# Wildfire           Male         -                  -                 -  -99.0
# Winter Soldier     Male     brown              Human             Brown  175.0
# Wolverine          Male      blue             Mutant             Black  160.0
# Wonder Man         Male       red                  -             Black  188.0
# X-Man              Male      blue                  -             Brown  175.0
# Yellowjacket       Male      blue              Human             Blond  183.0
# Ymir               Male     white        Frost Giant           No Hair  304.8
# Yoda               Male     brown     Yoda's species             White   66.0
# Zoom               Male       red                  -             Brown  185.0
#
#                           Publisher Skin color Alignment Weight
# name
# A-Bomb                Marvel Comics          -      good  441.0
# Abe Sapien        Dark Horse Comics       blue      good   65.0
# Abin Sur                  DC Comics        red      good   90.0
# Abomination           Marvel Comics          -       bad  441.0
# Abraxas               Marvel Comics          -       bad  -99.0
# Absorbing Man         Marvel Comics          -       bad  122.0
# Adam Monroe            NBC - Heroes          -      good  -99.0
# Adam Strange              DC Comics          -      good   88.0
# Agent Bob             Marvel Comics          -      good   81.0
# Agent Zero            Marvel Comics          -      good  104.0
# Air-Walker            Marvel Comics          -       bad  108.0
# Ajax                  Marvel Comics          -       bad   90.0
# Alan Scott                DC Comics          -      good   90.0
# Alex Mercer               Wildstorm          -       bad  -99.0
# Alex Woolsly           NBC - Heroes          -      good  -99.0
# Alien             Dark Horse Comics      black       bad  169.0
# Allan Quatermain          Wildstorm          -      good  -99.0
# Amazo                     DC Comics          -       bad  173.0
# Ammo                  Marvel Comics          -       bad  101.0
# Ando Masahashi         NBC - Heroes          -      good  -99.0
# Angel                 Marvel Comics          -      good   68.0
# Angel             Dark Horse Comics          -      good  -99.0
# Animal Man                DC Comics          -      good   83.0
# Annihilus             Marvel Comics          -       bad   90.0
# Ant-Man               Marvel Comics          -      good  122.0
# Ant-Man II            Marvel Comics          -      good   86.0
# Anti-Monitor              DC Comics          -       bad  -99.0
# Anti-Spawn             Image Comics          -       bad  -99.0
# Anti-Venom            Marvel Comics          -         -  358.0
# Apocalypse            Marvel Comics       grey       bad  135.0
# ...                             ...        ...       ...    ...
# Triton                Marvel Comics      green      good   86.0
# Ultron                Marvel Comics     silver       bad  331.0
# Utgard-Loki           Marvel Comics          -       bad   58.0
# Vanisher              Marvel Comics          -       bad   79.0
# Vegeta                     Shueisha          -       bad   73.0
# Venom                 Marvel Comics          -       bad  117.0
# Venom II              Marvel Comics          -       bad   50.0
# Venom III             Marvel Comics          -       bad  334.0
# Venompool             Marvel Comics          -         -  -99.0
# Vibe                      DC Comics          -      good   71.0
# Vindicator            Marvel Comics          -      good  -99.0
# Violator               Image Comics          -       bad  -99.0
# Vision                Marvel Comics        red      good  135.0
# Vulture               Marvel Comics          -       bad   79.0
# Walrus                Marvel Comics          -       bad  162.0
# War Machine           Marvel Comics          -      good   95.0
# Warlock               Marvel Comics          -      good  108.0
# Warp                      DC Comics          -       bad   67.0
# Warpath               Marvel Comics          -      good  158.0
# Watcher               Marvel Comics          -      good  -99.0
# Weapon XI             Marvel Comics          -       bad  -99.0
# Wildfire                  DC Comics          -      good  -99.0
# Winter Soldier        Marvel Comics          -      good  117.0
# Wolverine             Marvel Comics          -      good  135.0
# Wonder Man            Marvel Comics          -      good  171.0
# X-Man                 Marvel Comics          -      good   61.0
# Yellowjacket          Marvel Comics          -      good   83.0
# Ymir                  Marvel Comics      white      good  -99.0
# Yoda                   George Lucas      green      good   17.0
# Zoom                      DC Comics          -       bad   81.0
#
# [464 rows x 176 columns]

# %% [markdown]
# ## Some Initial Investigation
#
# Next, slice the DataFrame as needed and visualize the distribution of heights and weights by gender.  You should have 4 total plots.
#
# In the cell below:
#
# * Slice the DataFrame into separate DataFrames by gender
# * Complete the `show_distplot` function.  This helper function should take in a DataFrame, a string containing the gender we want to visualize, and and the column name we want to visualize by gender. The function should display a distplot visualization from seaborn of the column/gender combination.
#
# Hint: Don't forget to check the [seaborn documentation for distplot](https://seaborn.pydata.org/generated/seaborn.distplot.html) if you have questions about how to use it correctly!

# %%
male_heroes_df = None
female_heroes_df = None

def show_distplot(dataframe, gender, column_name):
    pass

# %%
# Male Height

# %%
# Male Weight

# %%
# Female Height

# %%
# Female Weight

# %% [markdown]
# Discuss your findings from the plots above, with respect to the distibution of height and weight by gender.  Your explanation should include discussion of any relevant summary statistics, including mean, median, mode, and the overall shape of each distribution.
#
# Wite your answer below this line:
# ____________________________________________________________________________________________________________________________

# %% [markdown]
# ### Sample Question: Most Common Powers
#
# The rest of this notebook will be left to you to investigate the dataset by formulating your own questions, and then seeking answers using pandas and numpy.  Every answer should include some sort of visualization, when appropriate. Before moving on to formulating your own questions, use the dataset to answer the following questions about superhero powers:
#
# * What are the 5 most common powers overall?
# * What are the 5 most common powers in the Marvel Universe?
# * What are the 5 most common powers in the DC Universe?

# %% [markdown]
# Analyze the results you found above to answer the following question:
#
# How do the top 5 powers in the Marvel and DC universes compare?  Are they similar, or are there significant differences? How do they compare to the overall trends in the entire Superheroes dataset?
#
# Wite your answer below this line:
# ____________________________________________________________________________________________________________________________
#
#
# ### Your Own Investigation
#
# For the remainder of this lab, you'll be focusing on coming up with and answering your own question, just like we did above.  Your question should not be overly simple, and should require both descriptive statistics and data visualization to answer.  In case you're unsure of what questions to ask, some sample questions have been provided below.
#
# Pick one of the following questions to investigate and answer, or come up with one of your own!
#
# * Which powers have the highest chance of co-occuring in a hero (e.g. super strength and flight), and does this differ by gender?
# * Is there a relationship between a hero's height and weight and their powerset?
# * What is the distribution of skin colors amongst alien heroes?
#
# Explain your question below this line:
# ____________________________________________________________________________________________________________________________
#
#
#
# Some sample cells have been provided to give you room to work. If you need to create more cells, you can do this easily by:
#
# 1. Highlighting a cell and then pressing `esc` to enter command mode.
# 1. Pressing `b` to add a cell below the currently highlighted cell, or `a` to add one above it.
#
# Be sure to include thoughtful, well-labeled visualizations to back up your analysis!

# %% [markdown]
# ## Summary
#
# In this lab, we demonstrated our mastery of:
# * Using all of our Pandas knowledge to date to clean the dataset and deal with null values
# * Using Queries and aggregations to group the data into interesting subsets as needed
# * Using descriptive statistics and data visualization to find answers to questions we may have about the data
